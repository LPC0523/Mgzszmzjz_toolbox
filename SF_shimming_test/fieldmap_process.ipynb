# %%
import os
import re
import glob
import shutil
import subprocess
import nibabel as nib
from nipype.interfaces.dcm2nii import Dcm2niix
from fsl.wrappers import bet, flirt, fslmaths
import numpy as np
import matplotlib
from scipy.ndimage import zoom
import SimpleITK as sitk
from scipy.optimize import least_squares
import matplotlib.pyplot as plt

# %%
source_directory = r'ash-0708_20250708-171343-1987_171422'
destination_directory = r'./SF_coil_profile'
keys = ['B0CH0','B0CH1','B0CH2','B0CH3','B0CH4','B0CH5','B0CH6','B0CH7',
        'B1CH0','B1CH1']
ch_names =['ch1','ch2','ch3','ch4','ch5','ch6','ch7','ch8',
           'ch9','ch10']
rename_dict = dict(zip(keys, ch_names))
pattern = re.compile(r"(" + "|".join(keys) + r")")

def rename_and_move_folders(source_directory, destination_directory):
    """ 遍历 source_directory，将匹配 bXchY 的文件夹重命名为 chX，并进一步分类 0.5n/0.5p """
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)

    for folder in os.listdir(source_directory):
        folder_path = os.path.join(source_directory, folder)
        
        if os.path.isdir(folder_path): 
            match = pattern.search(folder)
            if match:
                key = match.group(1) 
                new_name = rename_dict[key] 
                
                if "0.5n" in folder:
                    current_dir = "negative"
                elif "0.5p" in folder:
                    current_dir = "positive"
                else:
                    current_dir = "unknown"

                new_folder_path = os.path.join(destination_directory, new_name, current_dir, folder)

                os.makedirs(os.path.dirname(new_folder_path), exist_ok=True)
                
                shutil.move(folder_path, new_folder_path)
                print(f"Moved {folder} -> {new_folder_path}")

rename_and_move_folders(source_directory, destination_directory)
# Out:
# Moved B0CH5-0.5n_Echo2_180858_1502 -> ./SF_coil_profile/ch6/negative/B0CH5-0.5n_Echo2_180858_1502
# Moved B0CH6-0.5n_Echo2_181547_1702 -> ./SF_coil_profile/ch7/negative/B0CH6-0.5n_Echo2_181547_1702
# Moved B0CH6-0.5n_Echo1_181547_1701 -> ./SF_coil_profile/ch7/negative/B0CH6-0.5n_Echo1_181547_1701
# Moved B0CH2-0.5n_Echo2_174903_902 -> ./SF_coil_profile/ch3/negative/B0CH2-0.5n_Echo2_174903_902
# Moved B0CH1-0.5n_Echo1_174225_701 -> ./SF_coil_profile/ch2/negative/B0CH1-0.5n_Echo1_174225_701
# Moved B0CH5-0.5p_Echo1_180540_1401 -> ./SF_coil_profile/ch6/positive/B0CH5-0.5p_Echo1_180540_1401
# Moved B0CH2-0.5n_Echo1_174903_901 -> ./SF_coil_profile/ch3/negative/B0CH2-0.5n_Echo1_174903_901
# Moved B1CH0-0.5n_Echo1_182851_2101 -> ./SF_coil_profile/ch9/negative/B1CH0-0.5n_Echo1_182851_2101
# Moved B1CH0-0.5n_Echo2_182851_2102 -> ./SF_coil_profile/ch9/negative/B1CH0-0.5n_Echo2_182851_2102
# Moved B0CH2-0.5p_Echo1_174545_801 -> ./SF_coil_profile/ch3/positive/B0CH2-0.5p_Echo1_174545_801
# Moved B0CH7-0.5n_Echo1_182220_1901 -> ./SF_coil_profile/ch8/negative/B0CH7-0.5n_Echo1_182220_1901
# Moved B0CH5-0.5n_Echo1_180858_1501 -> ./SF_coil_profile/ch6/negative/B0CH5-0.5n_Echo1_180858_1501
# Moved B0CH3-0.5p_B0Map_175226_1003 -> ./SF_coil_profile/ch4/positive/B0CH3-0.5p_B0Map_175226_1003
# Moved B1CH1-0.5n_Echo2_183524_2302 -> ./SF_coil_profile/ch10/negative/B1CH1-0.5n_Echo2_183524_2302
# Moved B0CH0-0.5n_B0Map_173533_503 -> ./SF_coil_profile/ch1/negative/B0CH0-0.5n_B0Map_173533_503
# Moved B1CH1-0.5p_Echo1_183207_2201 -> ./SF_coil_profile/ch10/positive/B1CH1-0.5p_Echo1_183207_2201
# Moved B1CH0-0.5p_Echo2_182534_2002 -> ./SF_coil_profile/ch9/positive/B1CH0-0.5p_Echo2_182534_2002

# %%
def dcm2nii(dicom_directory, nifti_folder):
    """
    Converts DICOM files in each subdirectory within `dicom_directory` to NIfTI format and saves them in `nifti_folder`.

    Parameters:
        dicom_directory (str): Path to the directory containing DICOM subdirectories.
        nifti_folder (str): Path to the directory where NIfTI files will be saved.
    """
    directories = os.listdir(dicom_directory)
    
    for directory in directories:
        dicom_file_path = os.path.join(dicom_directory, directory)
        nifti_file_path = os.path.join(nifti_folder, f"{directory}_nii")
        
        converter = Dcm2niix()
        converter.inputs.source_dir = dicom_file_path
        converter.inputs.output_dir = nifti_file_path
    
        try:
            converter.run()
            print(f"Successfully converted {directory} to NIfTI format.")
        except Exception as e:
            print(f"Error converting {directory} to NIfTI: {e}")

# %%
def process_dicom_to_deltaB0(dicom_directory, nifti_folder, delta_TE, Frequency):
    """
    Converts DICOM files to NIfTI format, performs phase unwrapping, applies a brain mask, and calculates delta B0 maps.

    Parameters:
        dicom_directory (str): Path to the directory containing DICOM files.
        nifti_folder (str): Path to the directory where NIfTI files will be saved.
        delta_TE (float): Echo time difference in seconds.
        Frequency (float): Scanner frequency in MHz (e.g., 127.74 MHz for a 3T scanner).
    """
    print("启动！")
    directories = os.listdir(dicom_directory)

    for directory in directories:
        try:
            dicom_file_path = os.path.join(dicom_directory, directory)
            nifti_file_path = os.path.join(nifti_folder, f"{directory}_nii")
            os.makedirs(nifti_file_path, exist_ok=True)

            # Convert DICOM to NIfTI format
            converter = Dcm2niix()
            converter.inputs.source_dir = dicom_file_path
            converter.inputs.output_dir = nifti_file_path
            converter.run()
            # Identify phase and magnitude images
            phase_map = glob.glob(os.path.join(nifti_file_path, "*ph.nii.gz*"))
            magnitude_map = glob.glob(os.path.join(nifti_file_path, "*e2.nii.gz*"))

            if phase_map and magnitude_map:
                # Load the phase image and normalize it to range [-π, π]
                phase_map_nifti = nib.load(phase_map[0])
                phase_map_data = phase_map_nifti.get_fdata()
                affine = phase_map_nifti.affine.copy()
                header = phase_map_nifti.header.copy()

                phasemap = phase_map_data / 4096 * np.pi
                phase_map_img_valid = nib.Nifti1Image(phasemap, affine, header)
                phase_map_img_valid_path = os.path.join(nifti_file_path, f"{directory}_PhaseMap.nii.gz")
                nib.save(phase_map_img_valid, phase_map_img_valid_path)

                # Generate brain mask using BET (Brain Extraction Tool)
                bet_path = os.path.join(nifti_file_path, f"{directory}_bet.nii.gz")
                bet(magnitude_map[0], bet_path, f=0.1, m=True)

                # Apply the brain mask to the phase image
                mask_path = os.path.join(nifti_file_path, f"{directory}_bet_mask.nii.gz")
                brain_map_path = os.path.join(nifti_file_path, f"{directory}_BrainMap.nii.gz")
                fslmaths(phase_map_img_valid_path).mul(mask_path).run(brain_map_path)

                # Perform phase unwrapping
                unwrap_path = os.path.join(nifti_file_path, f"{directory}_unwrapped_Brain.nii.gz")
                cmd = [
                    "prelude",
                    "-p", brain_map_path,
                    "-a", magnitude_map[0],
                    "-o", unwrap_path
                ]
                subprocess.run(cmd, check=True)

                # Calculate delta B0 in Hz
                deltB0_hertz_path = os.path.join(nifti_file_path, f"{directory}_deltaB0_hertz.nii.gz")
                fslmaths(unwrap_path).div(2).div(np.pi).div(delta_TE).run(deltB0_hertz_path)

                # Calculate delta B0 in ppm
                deltB0_ppm_path = os.path.join(nifti_file_path, f"{directory}_deltaB0_ppm.nii.gz")
                fslmaths(deltB0_hertz_path).div(Frequency).run(deltB0_ppm_path)

                print(f"Processing completed for {directory}")
            else:
                print(f"Phase or magnitude images not found for {directory}")
        
        except Exception as e:
            print(f"Error processing {directory}: {e}")

# %%
# Paths for input DICOM and output NIfTI folders
root_directory = r'./SF_coil_profile'
nifti_folder = r'./SF_coil_profile_nii'

# Parameters for delta B0 calculation
delta_TE = 0.00246  # Echo time difference in seconds
Frequency = 42.58 * 5  # Scanner frequency in MHz for 5T
for dicom_directory in os.listdir(root_directory):
    ch_dicom_path = os.path.join(root_directory, dicom_directory)
    ch_nii_path = os.path.join(nifti_folder, f"{dicom_directory}_nii")
# Run the main processing and registration functions
    process_dicom_to_deltaB0(ch_dicom_path, ch_nii_path, delta_TE, Frequency)
# Out:
# 启动！
# 250708-22:00:19,880 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:19.880198:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:00:19,880 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:19.880198:Found 351 DICOM file(s)
# 250708-22:00:19,880 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:19.880198:Convert 117 DICOM as SF_coil_profile_nii/ch6_nii/positive_nii/positive_B0CH5-0.5p_20250708171404_1401 (132x118x117x1)
# 250708-22:00:19,941 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:19.941757:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch6_nii/positive_nii/positive_B0CH5-0.5p_20250708171404_1401.nii"
# 250708-22:00:19,942 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:19.941757:Convert 117 DICOM as SF_coil_profile_nii/ch6_nii/positive_nii/positive_B0CH5-0.5p_20250708171404_1402_e2 (132x118x117x1)
# 250708-22:00:20,0 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:19.999989:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch6_nii/positive_nii/positive_B0CH5-0.5p_20250708171404_1402_e2.nii"
# 250708-22:00:20,0 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:19.999989:Convert 117 DICOM as SF_coil_profile_nii/ch6_nii/positive_nii/positive_B0CH5-0.5p_20250708171404_1403_ph (132x118x117x1)
# 250708-22:00:20,35 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:20.035293:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch6_nii/positive_nii/positive_B0CH5-0.5p_20250708171404_1403_ph.nii"
# 250708-22:00:20,35 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:20.035293:Conversion required 0.204300 seconds (0.062041 for core code).
# Processing completed for positive
# 250708-22:00:24,719 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:24.718986:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:00:24,719 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:24.718986:Found 351 DICOM file(s)
# 250708-22:00:24,719 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:24.718986:Convert 117 DICOM as SF_coil_profile_nii/ch6_nii/negative_nii/negative_B0CH5-0.5n_20250708171404_
Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch4_nii/negative_nii/negative_B0CH3-0.5n_20250708171404_1101.nii"
# 250708-22:00:43,716 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:43.715911:Conversion required 0.175791 seconds (0.056680 for core code).
# Processing completed for negative
# 启动！
# 250708-22:00:48,354 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.354111:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:00:48,354 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.354111:Found 351 DICOM file(s)
# 250708-22:00:48,355 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.354111:Convert 117 DICOM as SF_coil_profile_nii/ch2_nii/positive_nii/positive_B0CH1-0.5p_20250708171404_601 (132x118x117x1)
# 250708-22:00:48,407 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.406991:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch2_nii/positive_nii/positive_B0CH1-0.5p_20250708171404_601.nii"
# 250708-22:00:48,407 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.406991:Convert 117 DICOM as SF_coil_profile_nii/ch2_nii/positive_nii/positive_B0CH1-0.5p_20250708171404_603_ph (132x118x117x1)
# 250708-22:00:48,438 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.438239:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch2_nii/positive_nii/positive_B0CH1-0.5p_20250708171404_603_ph.nii"
# 250708-22:00:48,438 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.438239:Convert 117 DICOM as SF_coil_profile_nii/ch2_nii/positive_nii/positive_B0CH1-0.5p_20250708171404_602_e2 (132x118x117x1)
# 250708-22:00:48,486 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.486224:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch2_nii/positive_nii/positive_B0CH1-0.5p_20250708171404_602_e2.nii"
# 250708-22:00:48,486 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:48.486224:Conversion required 0.173460 seconds (0.053004 for core code).
# Processing completed for positive
# 250708-22:00:53,64 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.064662:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:00:53,65 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.064662:Found 351 DICOM file(s)
# 250708-22:00:53,66 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.064662:Convert 117 DICOM as SF_coil_profile_nii/ch2_nii/negative_nii/negative_B0CH1-0.5n_20250708171404_702_e2 (132x118x117x1)
# 250708-22:00:53,118 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.118392:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch2_nii/negative_nii/negative_B0CH1-0.5n_20250708171404_702_e2.nii"
# 250708-22:00:53,118 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.118392:Convert 117 DICOM as SF_coil_profile_nii/ch2_nii/negative_nii/negative_B0CH1-0.5n_20250708171404_703_ph (132x118x117x1)
# 250708-22:00:53,153 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.153461:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch2_nii/negative_nii/negative_B0CH1-0.5n_20250708171404_703_ph.nii"
# 250708-22:00:53,154 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.153461:Convert 117 DICOM as SF_coil_profile_nii/ch2_nii/negative_nii/negative_B0CH1-0.5n_20250708171404_701 (132x118x117x1)
# 250708-22:00:53,201 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.201594:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch2_nii/negative_nii/negative_B0CH1-0.5n_20250708171404_701.nii"
# 250708-22:00:53,202 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:53.201594:Conversion required 0.179492 seconds (0.056180 for core code).
# Processing completed for negative
# 启动！
# 250708-22:00:57,752 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.751997:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:00:57,752 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.751997:Found 351 DICOM file(s)
# 250708-22:00:57,753 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.751997:Convert 117 DICOM as SF_coil_profile_nii/ch9_nii/positive_nii/positive_B1CH0-0.5p_20250708171404_2001 (132x118x117x1)
# 250708-22:00:57,803 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.803833:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch9_nii/positive_nii/positive_B1CH0-0.5p_20250708171404_2001.nii"
# 250708-22:00:57,804 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.803833:Convert 117 DICOM as SF_coil_profile_nii/ch9_nii/positive_nii/positive_B1CH0-0.5p_20250708171404_2003_ph (132x118x117x1)
# 250708-22:00:57,837 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.836973:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch9_nii/positive_nii/positive_B1CH0-0.5p_20250708171404_2003_ph.nii"
# 250708-22:00:57,837 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.836973:Convert 117 DICOM as SF_coil_profile_nii/ch9_nii/positive_nii/positive_B1CH0-0.5p_20250708171404_2002_e2 (132x118x117x1)
# 250708-22:00:57,886 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.886932:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch9_nii/positive_nii/positive_B1CH0-0.5p_20250708171404_2002_e2.nii"
# 250708-22:00:57,887 nipype.interface INFO:
# 	 stdout 2025-07-08T22:00:57.886932:Conversion required 0.177405 seconds (0.056264 for core code).
# Processing completed for positive
# 250708-22:01:02,497 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.497311:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:01:02,497 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.497311:Found 351 DICOM file(s)
# 250708-22:01:02,498 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.497311:Convert 117 DICOM as SF_coil_profile_nii/ch9_nii/negative_nii/negative_B1CH0-0.5n_20250708171404_2101 (132x118x117x1)
# 250708-22:01:02,549 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.549521:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch9_nii/negative_nii/negative_B1CH0-0.5n_20250708171404_2101.nii"
# 250708-22:01:02,550 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.549521:Convert 117 DICOM as SF_coil_profile_nii/ch9_nii/negative_nii/negative_B1CH0-0.5n_20250708171404_2102_e2 (132x118x117x1)
# 250708-22:01:02,599 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.599955:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch9_nii/negative_nii/negative_B1CH0-0.5n_20250708171404_2102_e2.nii"
# 250708-22:01:02,600 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.599955:Convert 117 DICOM as SF_coil_profile_nii/ch9_nii/negative_nii/negative_B1CH0-0.5n_20250708171404_2103_ph (132x118x117x1)
# 250708-22:01:02,630 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.630798:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch9_nii/negative_nii/negative_B1CH0-0.5n_20250708171404_2103_ph.nii"
# 250708-22:01:02,631 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:02.630798:Conversion required 0.174700 seconds (0.054697 for core code).
# Processing completed for negative
# 启动！
# 250708-22:01:06,662 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:06.662738:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:01:06,663 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:06.662738:Found 351 DICOM file(s)
# 250708-22:01:06,663 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:06.662738:Convert 117 DICOM as SF_coil_profile_nii/ch10_nii/positive_nii/positive_B1CH1-0.5p_20250708171404_
Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch8_nii/positive_nii/positive_B0CH7-0.5p_20250708171404_1801.nii"
# 250708-22:01:24,746 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:24.745645:Conversion required 0.170511 seconds (0.050502 for core code).
# Processing completed for positive
# 250708-22:01:29,329 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.329427:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:01:29,330 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.329427:Found 351 DICOM file(s)
# 250708-22:01:29,330 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.329427:Convert 117 DICOM as SF_coil_profile_nii/ch8_nii/negative_nii/negative_B0CH7-0.5n_20250708171404_1902_e2 (132x118x117x1)
# 250708-22:01:29,379 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.379483:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch8_nii/negative_nii/negative_B0CH7-0.5n_20250708171404_1902_e2.nii"
# 250708-22:01:29,380 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.379483:Convert 117 DICOM as SF_coil_profile_nii/ch8_nii/negative_nii/negative_B0CH7-0.5n_20250708171404_1901 (132x118x117x1)
# 250708-22:01:29,428 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.428521:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch8_nii/negative_nii/negative_B0CH7-0.5n_20250708171404_1901.nii"
# 250708-22:01:29,429 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.428521:Convert 117 DICOM as SF_coil_profile_nii/ch8_nii/negative_nii/negative_B0CH7-0.5n_20250708171404_1903_ph (132x118x117x1)
# 250708-22:01:29,459 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.459283:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch8_nii/negative_nii/negative_B0CH7-0.5n_20250708171404_1903_ph.nii"
# 250708-22:01:29,459 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:29.459283:Conversion required 0.171328 seconds (0.053073 for core code).
# Processing completed for negative
# 启动！
# 250708-22:01:34,65 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.065398:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:01:34,66 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.065398:Found 351 DICOM file(s)
# 250708-22:01:34,66 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.065398:Convert 117 DICOM as SF_coil_profile_nii/ch3_nii/positive_nii/positive_B0CH2-0.5p_20250708171404_803_ph (132x118x117x1)
# 250708-22:01:34,98 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.098680:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch3_nii/positive_nii/positive_B0CH2-0.5p_20250708171404_803_ph.nii"
# 250708-22:01:34,99 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.098680:Convert 117 DICOM as SF_coil_profile_nii/ch3_nii/positive_nii/positive_B0CH2-0.5p_20250708171404_802_e2 (132x118x117x1)
# 250708-22:01:34,149 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.149276:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch3_nii/positive_nii/positive_B0CH2-0.5p_20250708171404_802_e2.nii"
# 250708-22:01:34,149 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.149276:Convert 117 DICOM as SF_coil_profile_nii/ch3_nii/positive_nii/positive_B0CH2-0.5p_20250708171404_801 (132x118x117x1)
# 250708-22:01:34,198 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.198324:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch3_nii/positive_nii/positive_B0CH2-0.5p_20250708171404_801.nii"
# 250708-22:01:34,198 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:34.198324:Conversion required 0.174759 seconds (0.054249 for core code).
# Processing completed for positive
# 250708-22:01:38,777 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.777624:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:01:38,778 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.777624:Found 351 DICOM file(s)
# 250708-22:01:38,778 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.777624:Convert 117 DICOM as SF_coil_profile_nii/ch3_nii/negative_nii/negative_B0CH2-0.5n_20250708171404_903_ph (132x118x117x1)
# 250708-22:01:38,810 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.810586:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch3_nii/negative_nii/negative_B0CH2-0.5n_20250708171404_903_ph.nii"
# 250708-22:01:38,811 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.810586:Convert 117 DICOM as SF_coil_profile_nii/ch3_nii/negative_nii/negative_B0CH2-0.5n_20250708171404_902_e2 (132x118x117x1)
# 250708-22:01:38,861 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.861152:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch3_nii/negative_nii/negative_B0CH2-0.5n_20250708171404_902_e2.nii"
# 250708-22:01:38,861 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.861152:Convert 117 DICOM as SF_coil_profile_nii/ch3_nii/negative_nii/negative_B0CH2-0.5n_20250708171404_901 (132x118x117x1)
# 250708-22:01:38,910 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.910379:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch3_nii/negative_nii/negative_B0CH2-0.5n_20250708171404_901.nii"
# 250708-22:01:38,910 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:38.910379:Conversion required 0.174774 seconds (0.054742 for core code).
# Processing completed for negative
# 启动！
# 250708-22:01:43,559 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.559885:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:01:43,560 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.559885:Found 351 DICOM file(s)
# 250708-22:01:43,560 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.559885:Convert 117 DICOM as SF_coil_profile_nii/ch5_nii/positive_nii/positive_B0CH4-0.5p_20250708171404_1201 (132x118x117x1)
# 250708-22:01:43,611 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.611802:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch5_nii/positive_nii/positive_B0CH4-0.5p_20250708171404_1201.nii"
# 250708-22:01:43,612 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.611802:Convert 117 DICOM as SF_coil_profile_nii/ch5_nii/positive_nii/positive_B0CH4-0.5p_20250708171404_1203_ph (132x118x117x1)
# 250708-22:01:43,645 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.645047:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch5_nii/positive_nii/positive_B0CH4-0.5p_20250708171404_1203_ph.nii"
# 250708-22:01:43,645 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.645047:Convert 117 DICOM as SF_coil_profile_nii/ch5_nii/positive_nii/positive_B0CH4-0.5p_20250708171404_1202_e2 (132x118x117x1)
# 250708-22:01:43,693 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.693426:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch5_nii/positive_nii/positive_B0CH4-0.5p_20250708171404_1202_e2.nii"
# 250708-22:01:43,693 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:43.693426:Conversion required 0.175204 seconds (0.053209 for core code).
# Processing completed for positive
# 250708-22:01:48,306 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.306881:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) GCC13.2.0 x86-64 (64-bit Linux)
# 250708-22:01:48,307 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.306881:Found 351 DICOM file(s)
# 250708-22:01:48,307 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.306881:Convert 117 DICOM as SF_coil_profile_nii/ch5_nii/negative_nii/negative_B0CH4-0.5n_20250708171404_1302_e2 (132x118x117x1)
# 250708-22:01:48,358 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.358112:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch5_nii/negative_nii/negative_B0CH4-0.5n_20250708171404_1302_e2.nii"
# 250708-22:01:48,358 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.358112:Convert 117 DICOM as SF_coil_profile_nii/ch5_nii/negative_nii/negative_B0CH4-0.5n_20250708171404_1303_ph (132x118x117x1)
# 250708-22:01:48,389 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.389901:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch5_nii/negative_nii/negative_B0CH4-0.5n_20250708171404_1303_ph.nii"
# 250708-22:01:48,390 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.389901:Convert 117 DICOM as SF_coil_profile_nii/ch5_nii/negative_nii/negative_B0CH4-0.5n_20250708171404_1301 (132x118x117x1)
# 250708-22:01:48,436 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.436742:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "SF_coil_profile_nii/ch5_nii/negative_nii/negative_B0CH4-0.5n_20250708171404_1301.nii"
# 250708-22:01:48,437 nipype.interface INFO:
# 	 stdout 2025-07-08T22:01:48.436742:Conversion required 0.170843 seconds (0.051976 for core code).
# Processing completed for negative

# %%
for ch_nii in os.listdir(nifti_folder):
    ch_nii_path = os.path.join(nifti_folder, ch_nii)
    neg_path = os.path.join(ch_nii_path, "negative_nii")
    pos_path = os.path.join(ch_nii_path, "positive_nii")
    print(neg_path, pos_path)
    if os.path.exists(neg_path) and os.path.exists(pos_path):
        neg_hertz_fieldmap = [f for f in os.listdir(neg_path) if f.endswith("_hertz.nii.gz")]
        pos_hertz_fieldmap = [f for f in os.listdir(pos_path) if f.endswith("_hertz.nii.gz")]

        for neg_file, pos_file in zip(sorted(neg_hertz_fieldmap), sorted(pos_hertz_fieldmap)):
            neg_img = nib.load(os.path.join(neg_path, neg_file))
            pos_img = nib.load(os.path.join(pos_path, pos_file))

            neg_data = neg_img.get_fdata()
            pos_data = pos_img.get_fdata()

            delta_B0_fieldmap = pos_data - neg_data

            delta_img = nib.Nifti2Image(delta_B0_fieldmap, affine=neg_img.affine)
            delta_path = os.path.join(ch_nii_path,f"{ch_nii}_deltaFieldmap.nii.gz")

            nib.save(delta_img, delta_path)
            print(f"Save: {delta_path}")
# Out:
# ./SF_coil_profile_nii/ch9_nii/negative_nii ./SF_coil_profile_nii/ch9_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch9_nii/ch9_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch3_nii/negative_nii ./SF_coil_profile_nii/ch3_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch3_nii/ch3_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch4_nii/negative_nii ./SF_coil_profile_nii/ch4_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch4_nii/ch4_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch2_nii/negative_nii ./SF_coil_profile_nii/ch2_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch2_nii/ch2_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch1_nii/negative_nii ./SF_coil_profile_nii/ch1_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch1_nii/ch1_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch5_nii/negative_nii ./SF_coil_profile_nii/ch5_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch5_nii/ch5_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch6_nii/negative_nii ./SF_coil_profile_nii/ch6_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch6_nii/ch6_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch10_nii/negative_nii ./SF_coil_profile_nii/ch10_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch10_nii/ch10_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch8_nii/negative_nii ./SF_coil_profile_nii/ch8_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch8_nii/ch8_nii_deltaFieldmap.nii.gz
# ./SF_coil_profile_nii/ch7_nii/negative_nii ./SF_coil_profile_nii/ch7_nii/positive_nii
# Save: ./SF_coil_profile_nii/ch7_nii/ch7_nii_deltaFieldmap.nii.gz

# %%
infant_dicom = r"./dicom_infant"
infant_nii = r"./nii_infant"
process_dicom_to_deltaB0(infant_dicom, infant_nii, delta_TE, Frequency)
